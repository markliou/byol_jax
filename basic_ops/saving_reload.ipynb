# %%
import numpy as np 
import jax
import jax.numpy as jnp 
import flax.nnx 
import optax
import orbax.checkpoint as ocp

# %%
class sampleCnn(flax.nnx.Module):
    def __init__(self,
                 rngs,
                 *args, **kwargs):
        super(flax.nnx.Module, self).__init__(*args, **kwargs)
        
        self.rngs = rngs
        
        # input: [n, 128, 128, 3]
        self.conv1 = flax.nnx.Conv(3, 16, (3,3), strides=(2,2), rngs=self.rngs)
        self.conv2 = flax.nnx.Conv(16, 32, (3,3), strides=(2,2), rngs=self.rngs)
        self.conv3 = flax.nnx.Conv(32, 64, (3,3), strides=(2,2), rngs=self.rngs)
        
    def __call__(self, x):
        c1 = self.conv1(x)
        c2 = self.conv2(c1)
        c3 = self.conv3(c2)
        
        return c3

# %%
modelA = sampleCnn(rngs=flax.nnx.Rngs(0))
modelB = sampleCnn(rngs=flax.nnx.Rngs(1))
sampleInput = np.random.random([3, 128, 128, 3])
modelA(sampleInput) != modelB(sampleInput)
# Out:
# Array([[[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         ...,
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]],
#
#
#        [[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         ...,
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]],
#
#
#        [[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         ...,
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]]]], dtype=bool)

# %%
# saving model weights
graphdef, state = flax.nnx.split(modelA)

# orbax使用物件管理參數
ocpOptions = ocp.CheckpointManagerOptions(
    save_interval_steps=2,
    max_to_keep=2,
    # other options
)
checkpointer = ocp.CheckpointManager(
    '/workspaces/byol_jax/basic_ops/checkPoints/',
    options=ocpOptions,
    )

# validating how the orbax running
for test_step in range(10):
    checkpointer.save(step=test_step, args=ocp.args.StandardSave(state))
checkpointer.wait_until_finished() # orbax使用非同步執行儲存，所以需要等待他全部存完


# tutorial的方式，一定要使用絕對路徑。好像不是太直觀，因為會使用Test工具把原本的資料夾刪除
# ckpt_dir = ocp.test_utils.erase_and_create_empty('/workspaces/byol_jax/basic_ops/checkPoints/') # test_utils是方便測試用的，平常不太需要用
# checkpointer = ocp.StandardCheckpointer()
# checkpointer.save(ckpt_dir / 'state', state)
# Out:
# ERROR:absl:[process=0] Failed to run 1 Handler Commit operations or the Commit callback in background save thread, directory: /workspaces/byol_jax/basic_ops/checkPoints/2
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 207, in _thread_func
#     _background_wait_for_commit_futures(
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 125, in _background_wait_for_commit_futures
#     on_commit_callback()
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 403, in _callback
#     _on_commit_callback(
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 52, in _on_commit_callback
#     atomicity.on_commit_callback(
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/path/atomicity.py", line 563, in on_commit_callback
#     tmp_dir.finalize(
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/path/atomicity.py", line 298, in finalize
#     self._tmp_path.rename(self._final_path)
#   File "/usr/local/lib/python3.11/dist-packages/etils/epath/gpath.py", line 268, in rename
#     backend.rename(self._path_str, os.fspath(target))
#   File "/usr/local/lib/python3.11/dist-packages/etils/epath/backend.py", line 214, in rename
#     os.rename(path, dst)
# PermissionError: [Errno 13] Permission denied: '/workspaces/byol_jax/basic_ops/checkPoints/2.orbax-checkpoint-tmp-2' -> '/workspaces/byol_jax/basic_ops/checkPoints/2'
# ERROR:absl:[process=0][thread=MainThread][step=2][wait_until_finished] Save Finalize thread (save_finalize) failed.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py", line 1985, in wait_until_finished
#     self._finalize_thread.get_not_none().join()
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py", line 168, in join
#     raise self.exception
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py", line 155, in run
#     super().run()
#   File "/root/.local/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py", line 2061, in _finalize
#     self._wait_for_checkpointers()
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py", line 1945, in _wait_for_checkpointers
#     self._checkpointer.wait_until_finished()  # pytype: disable=attribute-error
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 554, in wait_until_finished
#     self._async_manager.wait_until_finished()
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 273, in wait_until_finished
#     self.check_for_errors()
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 248, in check_for_errors
#     raise exception  # pylint: disable=raising-bad-type
#     ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 207, in _thread_func
#     _background_wait_for_commit_futures(
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 125, in _background_wait_for_commit_futures
#     on_commit_callback()
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 403, in _callback
#     _on_commit_callback(
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py", line 52, in _on_commit_callback
#     atomicity.on_commit_callback(
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/path/atomicity.py", line 563, in on_commit_callback
#     tmp_dir.finalize(
#   File "/usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/path/atomicity.py", line 298, in finalize
#     self._tmp_path.rename(self._final_path)
#   File "/usr/local/lib/python3.11/dist-packages/etils/epath/gpath.py", line 268, in rename
#     backend.rename(self._path_str, os.fspath(target))
#   File "/usr/local/lib/python3.11/dist-packages/etils/epath/backend.py", line 214, in rename
#     os.rename(path, dst)
# PermissionError: [Errno 13] Permission denied: '/workspaces/byol_jax/basic_ops/checkPoints/2.orbax-checkpoint-tmp-2' -> '/workspaces/byol_jax/basic_ops/checkPoints/2'
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 17
#      15 # validating how the orbax running
#      16 for test_step in range(10):
# ---> 17     checkpointer.save(step=test_step, args=ocp.args.StandardSave(state))
#      18 checkpointer.wait_until_finished() # orbax使用非同步執行儲存，所以需要等待他全部存完
#      21 # tutorial的方式，一定要使用絕對路徑。好像不是太直觀，因為會使用Test工具把原本的資料夾刪除
#      22 # ckpt_dir = ocp.test_utils.erase_and_create_empty('/workspaces/byol_jax/basic_ops/checkPoints/') # test_utils是方便測試用的，平常不太需要用
#      23 # checkpointer = ocp.StandardCheckpointer()
#      24 # checkpointer.save(ckpt_dir / 'state', state)
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py:1284, in CheckpointManager.save(self, step, items, save_kwargs, metrics, force, args, custom_metadata)
#    1280 # Wait for ongoing saves to complete. Only applicable if some of the
#    1281 # checkpointers are AsyncCheckpointers.
#    1282 # Must happen after `should_save` to avoid blocking callers.
#    1283 step_stats.wait_for_prev_start_time = time.time()
# -> 1284 self.wait_until_finished()
#    1285 step_stats.wait_for_prev_duration_secs = (
#    1286     time.time() - step_stats.wait_for_prev_start_time
#    1287 )
#    1289 jax.monitoring.record_event_duration_secs(
#    1290     '/jax/checkpoint/write/wait_for_prev_duration_secs',
#    1291     step_stats.wait_for_prev_duration_secs,
#    1292 )
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py:1985, in CheckpointManager.wait_until_finished(self)
#    1974   logging.info(
#    1975       '[process=%s][thread=%s][step=%s][wait_until_finished] Waiting for'
#    1976       ' Save Finalize thread (%s) to complete.',
#    (...)   1980       finalize_thread_name,
#    1981   )
#    1982   # Let all threads join and wait for the finalize thread to complete.
#    1983   # Don't call join() with a lock otherwise we will end up serializing the
#    1984   # access to the finalize thread.
# -> 1985   self._finalize_thread.get_not_none().join()
#    1986   logging.info(
#    1987       '[process=%s][thread=%s][step=%s][wait_until_finished] Done'
#    1988       ' waiting for Save Finalize thread (%s) running at step=%d.',
#    (...)   1993       step,
#    1994   )
#    1995 except BaseException:  # pylint:disable=broad-exception-caught
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py:168, in _FinalizeThread.join(self, *args, **kwargs)
#     165 if self.exception and self._thread_local.should_raise:
#     166   # Each thread should only raise once.
#     167   self._thread_local.should_raise = False
# --> 168   raise self.exception
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py:155, in _FinalizeThread.run(self)
#     153 def run(self):
#     154   try:
# --> 155     super().run()
#     156   except BaseException as e:  # pylint:disable=broad-exception-caught
#     157     self.exception = e
#
# File ~/.local/lib/python3.11/site-packages/ipykernel/ipkernel.py:766, in IPythonKernel._initialize_thread_hooks.<locals>.run_closure(self)
#     764         else:
#     765             stream._thread_to_parent[self.ident] = parent
# --> 766 _threading_Thread_run(self)
#
# File /usr/lib/python3.11/threading.py:982, in Thread.run(self)
#     980 try:
#     981     if self._target is not None:
# --> 982         self._target(*self._args, **self._kwargs)
#     983 finally:
#     984     # Avoid a refcycle if the thread is running a function with
#     985     # an argument that has a member that points to the thread.
#     986     del self._target, self._args, self._kwargs
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py:2061, in CheckpointManager._finalize(self, step, steps_to_remove)
#    2059 current_thread = threading.current_thread()
#    2060 self._non_blocking_metadata_store.wait_until_finished()
# -> 2061 self._wait_for_checkpointers()
#    2062 # If an error is encountered while waiting for commit futures to complete,
#    2063 # we will not proceed past this point.
#    2064 self._finalize_checkpoint(step)
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/checkpoint_manager.py:1945, in CheckpointManager._wait_for_checkpointers(self)
#    1943 def _wait_for_checkpointers(self):
#    1944   if is_async_checkpointer(self._checkpointer):
# -> 1945     self._checkpointer.wait_until_finished()
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py:554, in AsyncCheckpointer.wait_until_finished(self)
#     552 def wait_until_finished(self):
#     553   """Waits for any outstanding operations to finish."""
# --> 554   self._async_manager.wait_until_finished()
#     555   self._metadata_store.wait_until_finished()
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py:273, in _AsyncManager.wait_until_finished(self)
#     264   self._thread = None
#     265   logging.info(
#     266       '[process=%s][thread=%s] Done with waiting for background save'
#     267       ' thread=%s.',
#    (...)    270       background_thread_name,
#     271   )
# --> 273 self.check_for_errors()
#     274 if background_thread_name is not None:
#     275   logging.info(
#     276       '[process=%s][thread=%s] No errors found in background save'
#     277       ' thread=%s.',
#    (...)    280       background_thread_name,
#     281   )
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py:248, in _AsyncManager.check_for_errors(self)
#     246 exception = self._exception
#     247 self._exception = None
# --> 248 raise exception
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py:207, in _AsyncManager._thread_func(self, directory, commit_futures, on_commit_callback)
#     205 """Awaits on commit futures and finalizes the checkpoint."""
#     206 try:
# --> 207   _background_wait_for_commit_futures(
#     208       directory,
#     209       commit_futures,
#     210       on_commit_callback,
#     211       barrier_sync_key_prefix=self._barrier_sync_key_prefix,
#     212       sync_fn=self._sync_fn,
#     213       primary_host=self._primary_host,
#     214   )
#     215 except Exception as e:  # pylint: disable=broad-exception-caught
#     216   msg = (
#     217       f'[process={multihost.process_index()}] Failed to run'
#     218       f' {len(commit_futures)} Handler Commit operations or the Commit'
#     219       f' callback in background save thread, directory: {directory}'
#     220   )
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py:125, in _background_wait_for_commit_futures(directory, commit_futures, on_commit_callback, barrier_sync_key_prefix, sync_fn, primary_host)
#     122     raise
#     124 if utils.is_primary_host(primary_host):
# --> 125   on_commit_callback()
#     126 if process_count > 1:
#     127   # Block until process 0 completes on_commit_callback.
#     128   sync_fn(
#     129       multihost.unique_barrier_key(
#     130           'async_commit_complete',
#    (...)    133       )
#     134   )
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py:403, in AsyncCheckpointer._make_on_commit_callback.<locals>._callback()
#     394   self._post_finalization_callback()
#     395 logging.vlog(
#     396     1,
#     397     '[process=%s][thread=%s] Async Save Callback [3/3]: Finalizing'
#    (...)    401     tmpdir.get(),
#     402 )
# --> 403 _on_commit_callback(
#     404     tmpdir,
#     405     checkpoint_start_time,
#     406 )
#     407 logging.info(
#     408     'Finished asynchronous save (blocking + background) in %.2f seconds'
#     409     ' to %s',
#     410     time.time() - checkpoint_start_time,
#     411     tmpdir.get_final(),
#     412 )
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/checkpointers/async_checkpointer.py:52, in _on_commit_callback(tmpdir, checkpoint_start_time)
#      47 def _on_commit_callback(
#      48     tmpdir: atomicity_types.TemporaryPath,
#      49     checkpoint_start_time: float,
#      50 ):
#      51   """Finalize atomic save and record checkpoint save metrics."""
# ---> 52   atomicity.on_commit_callback(
#      53       tmpdir,
#      54       checkpoint_start_time=checkpoint_start_time,
#      55   )
#      56   total_duration_secs = time.time() - checkpoint_start_time
#      57   jax.monitoring.record_event_duration_secs(
#      58       '/jax/checkpoint/write/async/total_duration_secs',
#      59       total_duration_secs,
#      60   )
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/path/atomicity.py:563, in on_commit_callback(tmp_dir, checkpoint_start_time)
#     549 def on_commit_callback(
#     550     tmp_dir: atomicity_types.TemporaryPath,
#     551     *,
#     552     checkpoint_start_time: float,
#     553 ):
#     554   """To commit save operation, atomically finalizes step dir.
#     555
#     556   Records save duration and lineage-logs step dir.
#    (...)    561     checkpoint_start_time: The time at which checkpoint saving began.
#     562   """
# --> 563   tmp_dir.finalize(
#     564   )
#     565   step_lib.record_saved_duration(checkpoint_start_time)
#     566   jax.monitoring.record_event('/jax/orbax/write/success')
#
# File /usr/local/lib/python3.11/dist-packages/orbax/checkpoint/_src/path/atomicity.py:298, in AtomicRenameTemporaryPath.finalize(self)
#     293   self._checkpoint_metadata_store.update(
#     294       file_path=checkpoint_metadata.step_metadata_file_path(self._tmp_path),
#     295       commit_timestamp_nsecs=time.time_ns(),
#     296   )
#     297   self._checkpoint_metadata_store.wait_until_finished()
# --> 298 self._tmp_path.rename(self._final_path)
#
# File /usr/local/lib/python3.11/dist-packages/etils/epath/gpath.py:268, in _GPath.rename(self, target)
#     266 target = self._new(target)
#     267 backend = _get_backend(self, target)
# --> 268 backend.rename(self._path_str, os.fspath(target))
#     269 return target
#
# File /usr/local/lib/python3.11/dist-packages/etils/epath/backend.py:214, in _OsPathBackend.rename(self, path, dst)
#     210 if self.exists(dst):
#     211   raise FileExistsError(
#     212       f'Cannot rename {path}. Destination {dst} already exists.'
#     213   )
# --> 214 os.rename(path, dst)
#
# PermissionError: [Errno 13] Permission denied: '/workspaces/byol_jax/basic_ops/checkPoints/2.orbax-checkpoint-tmp-2' -> '/workspaces/byol_jax/basic_ops/checkPoints/2'

# %%
graphdef, state = flax.nnx.split(modelB)

# 製作orbax物件讀取數據
ocpOptions = ocp.CheckpointManagerOptions(
    save_interval_steps=2,
    max_to_keep=2,
    # other options
    )
checkpointerLoader = ocp.CheckpointManager(
    '/workspaces/byol_jax/basic_ops/checkPoints/',
    options=ocpOptions,
    )

# 取得模型結構
# targetModelStateAbstract = jax.tree_map(ocp.tree.to_shape_dtype_struct, state)

restoreState = checkpointerLoader.restore(checkpointerLoader.latest_step())

modelB = flax.nnx.merge(graphdef, restoreState)

modelA(sampleInput) != modelB(sampleInput)
# Out:
# WARNING:absl:Item "default" was found in the checkpoint, but could not be restored. Please provide a `CheckpointHandlerRegistry`, or call `restore` with an appropriate `CheckpointArgs` subclass.
# WARNING:absl:Item "default" was found in the checkpoint, but could not be restored. Please provide a `CheckpointHandlerRegistry`, or call `restore` with an appropriate `CheckpointArgs` subclass.
# WARNING:absl:`StandardCheckpointHandler` expects a target tree to be provided for restore. Not doing so is generally UNSAFE unless you know the present topology to be the same one as the checkpoint was saved under.
# Array([[[[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         ...,
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]],
#
#
#        [[[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         ...,
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]],
#
#
#        [[[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         ...,
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]]]], dtype=bool)
